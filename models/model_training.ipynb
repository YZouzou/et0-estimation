# %% [markdown]
# # Training Models
# In this notebook, models for each region (and the general model) are fitted to the training data.
# The training is done using the `MyModel` class from ETProject.

# %%
from pathlib import Path
import os
import numpy as np
import pandas as pd

# %%
main_dir_path = Path.cwd().parents[0]
os.chdir(main_dir_path)

# %%
from ETProject.MyModel import MyModel, SVRRegressorRBF, PolynomialRegressor, RFRegressor, SVGPRegressorRBF

# %% [markdown]
# ### Training new models
#
# To train a new model define the following:
# * `region` to be trained. If None, all data is used (general model)
# * `regressor` to be used (See MyModel docs for more details)
# * `input_combo` number defined in *config_files/input_combinations*
# * `model_params` and `fit_params` of the regressor.
#
# If working in a different directory, make sure to modify `data_path` and `save_path`. (See MyModel docs for more details)
#
# The default performance metrics used by `MyModel` are RMSE, rRMSE, MAE, and NSE (R2). These can be modified by changing the default `score_fun_dict` argument. (See MyModel docs for more details)

# %%
# MyModel Docs
MyModel?

# %%
# Checking regressor class fit parameters
SVGPRegressorRBF.fit?

# %%
region = 'Black Sea'
input_combo = 3
regressor = SVGPRegressorRBF
model = MyModel(region=region,
                regressor=regressor,
                input_combo=input_combo,
                model_params={},
                fit_params={'M': 0.1, 'minibatch_size': 100, 'iterations': 10000, 'delay': 0})
# Out:
# Model not found at models/trained_models\SVGPR_RBF_black_sea_f3.joblib
# MyModel object created without model

# %%
# Fit the model
model.fit_model()

# Save the trained model, predictions, model parameters, and model performance metrics
# model.save()
# Out:
# Training model..
# ________________________________________
# #######################################
#
# Training done, training time: 214.2
# 0 second delay
# Train scores:
# MAE = 0.168
# RMSE = 0.230
# rRMSE = 0.070
# NSE = 0.977
#
#
# Test scores:
# MAE = 0.223
# RMSE = 0.293
# rRMSE = 0.089
# NSE = 0.965

# %% [markdown]
# The modelling can be done for all regions and input combinations using the following cell. Note that this will take a very long time to run when training SVR or GPR models.

# %%
regressor = SVRRegressorRBF

for region in regions:
    for input_combo in range(1, 17):
        model = MyModel(
            region=region,
            regressor=regressor,
            input_combo=input_combo,
            model_params={},
            fit_params={'C': [1, 5, 20, 50], 'gamma': [0.1, 0.3, 0.5], 'cv': 4})
        
        # Uncomment to fit and save models
#         model.fit_model()
#         model.save()

# %% [markdown]
# ### Loading existing models
# To load a saved model define the following:
# * `region` to be trained. If None, all data is used (general model)
# * `algorithm`
# * `input_combo`

# %%
region = 'Black Sea'
input_combo = 15
algorithm = 'SVR'

model = MyModel(region=region,
                algorithm=algorithm,
                input_combo=input_combo)
# Out:
# SVR_black_sea_f15 model loaded from models/

# %%
# Input features
model.feature_names
# Out:
# ['maximum_temperature',
#  'average_wind_speed',
#  'month',
#  'average_solar_radiation']

# %%
# Generate prediction
input_vals = np.array([35, 2, 5, 7]).reshape(1, len(model.feature_names))
model.model.predict(input_vals)
# Out:
# array([4.83964974])

# %%
# Train and test dataset scores
model.get_scores(predict=False)
# Out:
# Train scores:
# MAE = 0.096
# RMSE = 0.136
# rRMSE = 0.041
# NSE = 0.992
#
#
# Test scores:
# MAE = 0.129
# RMSE = 0.168
# rRMSE = 0.051
# NSE = 0.988

# %%
model.get_station_scores()
# Out:
#            model_name algorithm     region  input_combo  st_num dataset  \
# 0   SVR_black_sea_f15   SVR_RBF  Black Sea           15   17020    test
# 1   SVR_black_sea_f15   SVR_RBF  Black Sea           15   17033    test
# 2   SVR_black_sea_f15   SVR_RBF  Black Sea           15   17045    test
# 3   SVR_black_sea_f15   SVR_RBF  Black Sea           15   17077    test
# 4   SVR_black_sea_f15   SVR_RBF  Black Sea           15   17618    test
# 5   SVR_black_sea_f15   SVR_RBF  Black Sea           15   17624    test
# 6   SVR_black_sea_f15   SVR_RBF  Black Sea           15   17648    test
# 7   SVR_black_sea_f15   SVR_RBF  Black Sea           15   17650    test
# 8   SVR_black_sea_f15   SVR_RBF  Black Sea           15   17646   train
# 9   SVR_black_sea_f15   SVR_RBF  Black Sea           15   17070   train
# 10  SVR_black_sea_f15   SVR_RBF  Black Sea           15   17772   train
# 11  SVR_black_sea_f15   SVR_RBF  Black Sea           15   17602   train
# 12  SVR_black_sea_f15   SVR_RBF  Black Sea           15   17085   train
# 13  SVR_black_sea_f15   SVR_RBF  Black Sea           15   17072   train
# 14  SVR_black_sea_f15   SVR_RBF  Black Sea           15   17074   train
# 15  SVR_black_sea_f15   SVR_RBF  Black Sea           15   17606   train
# 16  SVR_black_sea_f15   SVR_RBF  Black Sea           15   17034   train
# 17  SVR_black_sea_f15   SVR_RBF  Black Sea           15   17088   train
# 18  SVR_black_sea_f15   SVR_RBF  Black Sea           15   17015   train
# 19  SVR_black_sea_f15   SVR_RBF  Black Sea           15   18904   train
#
#          MAE      RMSE     rRMSE       NSE
# 0   0.072193  0.093801  0.029451  0.995932
# 1   0.146249  0.178119  0.061015  0.969455
# 2   0.138238  0.166267  0.049916  0.989612
# 3   0.236910  0.267776  0.070063  0.984739
# 4   0.184550  0.242411  0.071813  0.965510
# 5   0.163841  0.195427  0.066504  0.971523
# 6   0.084909  0.108983  0.030857  0.995951
# 7   0.114005  0.142889  0.040408  0.994473
# 8   0.201693  0.253852  0.076013  0.962455
# 9   0.060316  0.081180  0.025482  0.997214
# 10  0.220941  0.277753  0.086670  0.904847
# 11  0.136061  0.167746  0.037074  0.981263
# 12  0.063613  0.085922  0.024279  0.997537
# 13  0.053151  0.068953  0.025102  0.997245
# 14  0.059787  0.076821  0.025592  0.997235
# 15  0.137714  0.168687  0.046602  0.983729
# 16  0.135596  0.165102  0.057600  0.973124
# 17  0.069479  0.093468  0.026567  0.997761
# 18  0.105958  0.142121  0.045398  0.979921
# 19  0.085204  0.111751  0.043182  0.989654
